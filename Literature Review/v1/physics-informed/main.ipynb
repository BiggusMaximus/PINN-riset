# %% [markdown]
# # **Kalau belum install**

# %%
import subprocess

def install_packages():
    # List of packages to install
    packages = [
        "pandas",
        "numpy",
        "matplotlib",
        "pycountry"
    ]

    # Install each package
    for package in packages:
        try:
            print(f"Installing {package}...")
            subprocess.check_call(["pip", "install", package])
            print(f"Successfully installed {package}.\n")
        except subprocess.CalledProcessError as e:
            print(f"Failed to install {package}. Error: {e}\n")

install_packages()
# Out:
# Installing pandas...
# Successfully installed pandas.
#
# Installing numpy...
# Successfully installed numpy.
#
# Installing matplotlib...
# Successfully installed matplotlib.
#
# Installing pycountry...
# Successfully installed pycountry.

# %% [markdown]
# # **Install Libraries**

# %%
import pandas as pd
import os, time, csv, re
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
from collections import Counter
import pycountry
import re
from collections import defaultdict

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %% [markdown]
# # **Parameter**

# %%
FILE_NAME = 'scopus.csv'

# %% [markdown]
# # **Data Preprocessing**

# %%
df = pd.read_csv(FILE_NAME)
df
# Out:
#                                                 Authors  \
# 0     Mu S.; Sun X.; Dong Z.; Yang H.; Liu Y.; Zhang...
# 1                       Ma Z.; Jiang G.; Hu Y.; Chen J.
# 2                             Zhang Z.; Hou Y.; Yuan Y.
# 3                               Noh H.; Lee J.; Yoon E.
# 4                      Zhang Z.-Y.; Li J.-Y.; Guo L.-L.
# ...                                                 ...
# 5995                           Uy W.I.T.; Grigoriu M.D.
# 5996                                  Chen Y.; Zhang D.
# 5997                              Geneva N.; Zabaras N.
# 5998                           Zhang R.; Liu Y.; Sun H.
# 5999                      Karda K.; Mouli C.; Alam M.A.
#
#                                       Author full names  \
# 0     Mu, Shibo (57209369179); Sun, Xingwei (5945843...
# 1     Ma, Zhihao (57225918528); Jiang, Gang (5870447...
# 2     Zhang, Zhenhuan (57999658000); Hou, Yutian (57...
# 3     Noh, Hyeongjun (59471848100); Lee, Jimin (5794...
# 4     Zhang, Zhi-Yong (57077316900); Li, Jie-Ying (5...
# ...                                                 ...
# 5995  Uy, Wayne Isaac T. (53878891700); Grigoriu, Mi...
# 5996  Chen, Yuntian (57190944201); Zhang, Dongxiao (...
# 5997  Geneva, Nicholas (57190393795); Zabaras, Nicho...
# 5998  Zhang, Ruiyang (57005704300); Liu, Yang (57216...
# 5999  Karda, K. (35772383500); Mouli, Chandra (66024...
#
#                                            Author(s) ID  \
# 0     57209369179; 59458439100; 56335850700; 5720427...
# 1     57225918528; 58704478200; 57202533465; 5719402...
# 2                 57999658000; 57901558800; 56374779600
# 3                 59471848100; 57947107800; 56909497400
# 4                 57077316900; 58083375000; 41761465500
# ...                                                 ...
# 5995                            53878891700; 7102885718
# 5996                           57190944201; 57034330100
# 5997                            57190393795; 7006370831
# 5998              57005704300; 57216532764; 55792579200
# 5999               35772383500; 6602455006; 58631630100
#
#                                                   Title  Year  \
# 0     Meshing theory of point-contact conical-envelo...  2025
# 1     A review of physics-informed machine learning ...  2025
# 2     A novel physical information neural network fo...  2025
# 3     FPL-net: A deep learning framework for solving...  2025
# 4     Invariant deep neural networks under the finit...  2025
# ...                                                 ...   ...
# 5995  Neural network representation of the probabili...  2020
# 5996  Physics-Constrained Deep Learning of Geomechan...  2020
# 5997  Modeling the dynamics of PDE systems with phys...  2020
# 5998  Physics-informed multi-LSTM networks for metam...  2020
# 5999  Design Principles of Self-Compensated NBTI-Fre...  2020
#
#                                            Source title Volume Issue Art. No.  \
# 0                          Mechanism and Machine Theory    205   NaN   105870
# 1                                        Applied Energy    381   NaN   125169
# 2                                      Renewable Energy    240   NaN   122166
# 3                      Journal of Computational Physics    523   NaN   113665
# 4                      Journal of Computational Physics    523   NaN   113680
# ...                                                 ...    ...   ...      ...
# 5995                                              Chaos     30     9   093118
# 5996  IEEE Transactions on Geoscience and Remote Sen...     58     8  9007020
# 5997                   Journal of Computational Physics    403   NaN   109056
# 5998  Computer Methods in Applied Mechanics and Engi...    369   NaN   113226
# 5999              IEEE Transactions on Electron Devices     67     6  9076612
#
#      Page start  ... ISBN  CODEN   PubMed ID Language of Original Document  \
# 0           NaN  ...  NaN  MHMTA         NaN                       English
# 1           NaN  ...  NaN  APEND         NaN                       English
# 2           NaN  ...  NaN    NaN         NaN                       English
# 3           NaN  ...  NaN  JCTPA         NaN                       English
# 4           NaN  ...  NaN  JCTPA         NaN                       English
# ...         ...  ...  ...    ...         ...                           ...
# 5995        NaN  ...  NaN    NaN  33003919.0                       English
# 5996       5932  ...  NaN  IGRSD         NaN                       English
# 5997        NaN  ...  NaN  JCTPA         NaN                       English
# 5998        NaN  ...  NaN  CMMEC         NaN                       English
# 5999       2238  ...  NaN  IETDA         NaN                       English
#
#               Abbreviated Source Title Document Type Publication Stage  \
# 0                     Mech Mach Theory       Article             Final
# 1                         Appl. Energy       Article             Final
# 2                        Renew. Energy       Article             Final
# 3                     J. Comput. Phys.       Article             Final
# 4                     J. Comput. Phys.       Article             Final
# ...                                ...           ...               ...
# 5995                             Chaos       Article             Final
# 5996     IEEE Trans Geosci Remote Sens       Article             Final
# 5997                  J. Comput. Phys.       Article             Final
# 5998  Comput. Methods Appl. Mech. Eng.       Article             Final
# 5999      IEEE Trans. Electron Devices       Article             Final
#
#                                             Open Access  Source  \
# 0                                                   NaN  Scopus
# 1                                                   NaN  Scopus
# 2                                                   NaN  Scopus
# 3              All Open Access; Hybrid Gold Open Access  Scopus
# 4                    All Open Access; Green Open Access  Scopus
# ...                                                 ...     ...
# 5995  All Open Access; Bronze Open Access; Green Ope...  Scopus
# 5996           All Open Access; Hybrid Gold Open Access  Scopus
# 5997  All Open Access; Bronze Open Access; Green Ope...  Scopus
# 5998  All Open Access; Bronze Open Access; Green Ope...  Scopus
# 5999                All Open Access; Bronze Open Access  Scopus
#
#                      EID
# 0     2-s2.0-85211025849
# 1     2-s2.0-85212587131
# 2     2-s2.0-85212345167
# 3     2-s2.0-85211978914
# 4     2-s2.0-85212580064
# ...                  ...
# 5995  2-s2.0-85092381705
# 5996  2-s2.0-85089244037
# 5997  2-s2.0-85075382514
# 5998  2-s2.0-85086889624
# 5999  2-s2.0-85085542982
#
# [6000 rows x 46 columns]

# %% [markdown]
# # **PRISMA Framework**

# %%
for i in df.columns:
    print(i)
# Out:
# Authors
# Author full names
# Author(s) ID
# Title
# Year
# Source title
# Volume
# Issue
# Art. No.
# Page start
# Page end
# Page count
# Cited by
# DOI
# Link
# Affiliations
# Authors with affiliations
# Abstract
# Author Keywords
# Index Keywords
# Molecular Sequence Numbers
# Chemicals/CAS
# Tradenames
# Manufacturers
# Funding Details
# Funding Texts
# References
# Correspondence Address
# Editors
# Publisher
# Sponsors
# Conference name
# Conference date
# Conference location
# Conference code
# ISSN
# ISBN
# CODEN
# PubMed ID
# Language of Original Document
# Abbreviated Source Title
# Document Type
# Publication Stage
# Open Access
# Source
# EID
